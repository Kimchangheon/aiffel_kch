# %%
file = """
import csv
import io
import json
import os

os.environ["CUDA_VISIBLE_DEVICES"] = '-1' #CPU 사용
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

workdir = os.path.join(os.getenv('HOME'),'aiffel/mpii')
os.chdir(workdir)

from loguru import logger
from PIL import Image
import ray
import tensorflow as tf

num_train_shards = 64
num_val_shards = 8
ray.init()
tf.get_logger().setLevel('ERROR')
"""

# %%
file_list = file.split("\n")

# %%
with open('your_file.py', 'w') as f:
    for item in file_list:
        f.write("%s\n" % item)

# %%
# !python your_file.py
# Out:
# Traceback (most recent call last):
#   File "your_file.py", line 11, in <module>
#     os.chdir(workdir)
# FileNotFoundError: [Errno 2] No such file or directory: '/root/aiffel/mpii'

# %%
file = '''
asdf
asdf
asdf
'''

# %%
file
# Out:
# '\nasdf\nasdf\nasdf\n'

# %%
# !echo "\n asdf \n asdf \n asdf \n " > file.txt

# %%
# !echo file.txt
# Out:
# file.txt

# %%
# !cat $file
# Out:
# ^C

# %%
# !echo $file
# Out:
# /bin/bash: line 1: import: command not found
# /bin/bash: line 2: import: command not found
# /bin/bash: line 3: import: command not found
# /bin/bash: line 4: import: command not found
# /bin/bash: line 6: os.environ[CUDA_VISIBLE_DEVICES]: command not found
# /bin/bash: line 7: os.environ[TF_CPP_MIN_LOG_LEVEL]: command not found
# /bin/bash: -c: line 9: syntax error near unexpected token `('
# /bin/bash: -c: line 9: `workdir = os.path.join(os.getenv('HOME'),'aiffel/mpii')'

# %%
# !echo $file > file.txt
# Out:
# /bin/bash: line 1: import: command not found
# /bin/bash: line 2: import: command not found
# /bin/bash: line 3: import: command not found
# /bin/bash: line 4: import: command not found
# /bin/bash: line 6: os.environ[CUDA_VISIBLE_DEVICES]: command not found
# /bin/bash: line 7: os.environ[TF_CPP_MIN_LOG_LEVEL]: command not found
# /bin/bash: -c: line 9: syntax error near unexpected token `('
# /bin/bash: -c: line 9: `workdir = os.path.join(os.getenv('HOME'),'aiffel/mpii')'

# %%
# !printf $file > file.txt
# Out:
# printf: usage: printf [-v var] format [arguments]
# /bin/bash: line 1: import: command not found
# /bin/bash: line 2: import: command not found
# /bin/bash: line 3: import: command not found
# /bin/bash: line 4: import: command not found
# /bin/bash: line 6: os.environ[CUDA_VISIBLE_DEVICES]: command not found
# /bin/bash: line 7: os.environ[TF_CPP_MIN_LOG_LEVEL]: command not found
# /bin/bash: -c: line 9: syntax error near unexpected token `('
# /bin/bash: -c: line 9: `workdir = os.path.join(os.getenv('HOME'),'aiffel/mpii')'

# %%
file
# Out:
# '\nimport csv\nimport io\nimport json\nimport os\n\nos.environ["CUDA_VISIBLE_DEVICES"] = \'-1\' #CPU 사용\nos.environ[\'TF_CPP_MIN_LOG_LEVEL\'] = \'3\'\n\nworkdir = os.path.join(os.getenv(\'HOME\'),\'aiffel/mpii\')\nos.chdir(workdir)\n\nfrom loguru import logger\nfrom PIL import Image\nimport ray\nimport tensorflow as tf\n\nnum_train_shards = 64\nnum_val_shards = 8\nray.init()\ntf.get_logger().setLevel(\'ERROR\')\n'

# %%
# !echo '\nimport csv\nimport io\nimport json\nimport os\n\nos.environ["CUDA_VISIBLE_DEVICES"] = \'-1\' #CPU 사용\nos.environ[\'TF_CPP_MIN_LOG_LEVEL\'] = \'3\'\n\nworkdir = os.path.join(os.getenv(\'HOME\'),\'aiffel/mpii\')\nos.chdir(workdir)\n\nfrom loguru import logger\nfrom PIL import Image\nimport ray\nimport tensorflow as tf\n\nnum_train_shards = 64\nnum_val_shards = 8\nray.init()\ntf.get_logger().setLevel(\'ERROR\')\n' >> file.txt
# Out:
# \nimport csv\nimport io\nimport json\nimport os\n\nos.environ["CUDA_VISIBLE_DEVICES"] = \-1'

# %%
printf "\nimport csv\nimport io\nimport json\nimport os\n\nos.environ["CUDA_VISIBLE_DEVICES"] = \'-1\' #CPU 사용\nos.environ[\'TF_CPP_MIN_LOG_LEVEL\'] = \'3\'\n\nworkdir = os.path.join(os.getenv(\'HOME\'),\'aiffel/mpii\')\nos.chdir(workdir)\n\nfrom loguru import logger\nfrom PIL import Image\nimport ray\nimport tensorflow as tf\n\nnum_train_shards = 64\nnum_val_shards = 8\nray.init()\ntf.get_logger().setLevel(\'ERROR\')\n" > file.txt
# Out:
#   File "<ipython-input-11-3f9d6322cc35>", line 1
#     printf "\nimport csv\nimport io\nimport json\nimport os\n\nos.environ["CUDA_VISIBLE_DEVICES"] = \'-1\' #CPU 사용\nos.environ[\'TF_CPP_MIN_LOG_LEVEL\'] = \'3\'\n\nworkdir = os.path.join(os.getenv(\'HOME\'),\'aiffel/mpii\')\nos.chdir(workdir)\n\nfrom loguru import logger\nfrom PIL import Image\nimport ray\nimport tensorflow as tf\n\nnum_train_shards = 64\nnum_val_shards = 8\nray.init()\ntf.get_logger().setLevel(\'ERROR\')\n" > file.txt
#                                                                           ^
# SyntaxError: invalid syntax

# %%
\nimport csv\nimport io\nimport json\nimport os\n\nos.environ["CUDA_VISIBLE_DEVICES"] = \'-1\' #CPU 사용\nos.environ[\'TF_CPP_MIN_LOG_LEVEL\'] = \'3\'\n\nworkdir = os.path.join(os.getenv(\'HOME\'),\'aiffel/mpii\')\nos.chdir(workdir)\n\nfrom loguru import logger\nfrom PIL import Image\nimport ray\nimport tensorflow as tf\n\nnum_train_shards = 64\nnum_val_shards = 8\nray.init()\ntf.get_logger().setLevel(\'ERROR\')\n
# Out:
#   File "<ipython-input-12-1fd15eb5a5c5>", line 1
#     \nimport csv\nimport io\nimport json\nimport os\n\nos.environ["CUDA_VISIBLE_DEVICES"] = \'-1\' #CPU 사용\nos.environ[\'TF_CPP_MIN_LOG_LEVEL\'] = \'3\'\n\nworkdir = os.path.join(os.getenv(\'HOME\'),\'aiffel/mpii\')\nos.chdir(workdir)\n\nfrom loguru import logger\nfrom PIL import Image\nimport ray\nimport tensorflow as tf\n\nnum_train_shards = 64\nnum_val_shards = 8\nray.init()\ntf.get_logger().setLevel(\'ERROR\')\n
#                                                                                                                                                                                                                                                                                                                                                                                                                                    ^
# SyntaxError: unexpected character after line continuation character

# %%
[오후 4:10] 우성우
    
WARNING:tensorflow:AutoGraph could not transform <function create_dataset at 0x7fdcfa5a0b00> and will run it as-is.
Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
Cause: module 'gast' has no attribute 'Index'
To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
WARNING:tensorflow:AutoGraph could not transform <preprocess.Preprocessor object at 0x7fdcf04575d0> and will run it as-is.
Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
Cause: module 'gast' has no attribute 'Index'
To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
Traceback (most recent call last):
  File "train.py", line 252, in <module>
    num_heatmap, batch_size, train_tfrecords, val_tfrecords, '0.0.1')
  File "/home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
    result = self._call(*args, **kwds)
  File "/home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 871, in _call
    self._initialize(args, kwds, add_initializers_to=initializers)
  File "/home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 726, in _initialize
    *args, **kwds))
  File "/home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 2969, in _get_concrete_function_internal_garbage_collected
    graph_function, _ = self._maybe_define_function(args, kwargs)
  File "/home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 3361, in _maybe_define_function
    graph_function = self._create_graph_function(args, kwargs)
  File "/home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 3206, in _create_graph_function
    capture_by_value=self._capture_by_value),
  File "/home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py", line 990, in func_graph_from_py_func
    func_outputs = python_func(*func_args, **func_kwargs)
  File "/home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 634, in wrapped_fn
    out = weak_wrapped_fn().__wrapped__(*args, **kwds)
  File "/home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py", line 977, in wrapper
    raise e.ag_error_metadata.to_exception(e)
tensorflow.python.framework.errors_impl.OperatorNotAllowedInGraphError: in user code:


    train.py:204 train  *
        train_dataset = create_dataset(
    train.py:189 create_dataset  **
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    /home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py:1812 map
        preserve_cardinality=True)
    /home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py:4246 __init__
        use_legacy_function=use_legacy_function)
    /home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py:3525 __init__
        self._function = wrapper_fn.get_concrete_function()
    /home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/function.py:3052 get_concrete_function
        *args, **kwargs)
    /home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/function.py:3019 _get_concrete_function_garbage_collected
        graph_function, _ = self._maybe_define_function(args, kwargs)
    /home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/function.py:3361 _maybe_define_function
        graph_function = self._create_graph_function(args, kwargs)
    /home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/function.py:3206 _create_graph_function
        capture_by_value=self._capture_by_value),
    /home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py:990 func_graph_from_py_func
        func_outputs = python_func(*func_args, **func_kwargs)
    /home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py:3518 wrapper_fn
        ret = _wrapper_helper(*args)
    /home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py:3453 _wrapper_helper
        ret = autograph.tf_convert(func, ag_ctx)(*nested_args)
    /home/woosungwoo/aiffel/mpii/preprocess.py:18 __call__  **
        image, keypoint_x, keypoint_y = self.crop_roi(image, features, margin=random_margin)
    /home/woosungwoo/aiffel/mpii/preprocess.py:77 crop_roi
        effective_xmin = xmin if xmin > 0 else 0
    /home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/framework/ops.py:885 __bool__
        self._disallow_bool_casting()
    /home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/framework/ops.py:489 _disallow_bool_casting
        "using a `tf.Tensor` as a Python `bool`")
    /home/woosungwoo/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/framework/ops.py:476 _disallow_when_autograph_enabled
        " indicate you are trying to use an unsupported feature.".format(task))


    OperatorNotAllowedInGraphError: using a `tf.Tensor` as a Python `bool` is not allowed: AutoGraph did convert this function. This might indicate you are trying to use an unsupported feature.
