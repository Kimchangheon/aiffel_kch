# %%
# !mkdir -p ~/aiffel/rock_scissor_paper    
# !ln -s /content/*.zip ~/aiffel/rock_scissor_paper
# !cd ~/aiffel/rock_scissor_paper && unzip data.zip
# !ls ~/aiffel/rock_scissor_paper/data
# Out:
# ln: failed to create symbolic link '/root/aiffel/rock_scissor_paper/data.zip': File exists
# unzip:  cannot find or open data.zip, data.zip.zip or data.zip.ZIP.
# ls: cannot access '/root/aiffel/rock_scissor_paper/data': No such file or directory
